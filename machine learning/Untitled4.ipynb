# %%
class Atm:
  def __init__(self):
    self.pin=""
    self.balance=0
    self.menu()

  def menu(self):
    while True
    user_input=input("""
                  Hello how would you like to proceed
                  1)1 to create pin
                  2)2 to deposit
                  3)3 to withdraw
                  4)to check balance click 4
                  5)5 to exit""")
    if user_input=="1":
      print("create pin")
      self.create_pin()
    elif user_input=="2":
      print("deposit")
      self.deposit()
    elif user_input=="3":
      print("to withdraw")
      self.withdraw()
    elif user_input=="4":
      print("check balance")
      self.check_balance()
    else:
      print("bye")

  def create_pin(self):
    self.pin=input("enter the pin")
    print("pin set succsefully")

  def deposit(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      amount=int(input("enter thr amount to be deposited"))
      self.balance+=amount
      print("deposit succsef")

  def withdraw(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      amount=int(input("enter thr amount"))
      if amount<=self.balance:
        self.balance-=amount
        print("operation succsefull")
      else:
        print("insufficient balance")
    else:
      print("incorrect pin)")

  def check_balance(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      print("your balance is",self.balance)
    else:
      print("incorrect pin")

obj=Atm()
# Out:
#   File "/tmp/ipykernel_2017/3290812524.py", line 8
#     while True
#               ^
# SyntaxError: expected ':'

# %%
class Atm:
  def __init__(self):
    self.pin=""
    self.balance=0
    self.menu()

  def menu(self):
    user_input=input("""
                  Hello how would you like to proceed
                  1)1 to create pin
                  2)2 to deposit
                  3)3 to withdraw
                  4)to check balance click 4
                  5)5 to exit""")

    if user_input=="1":
      print("create pin")
      self.create_pin()

    elif user_input=="2":
      print("deposit")
      self.deposit()

    elif user_input=="3":
      print("to withdraw")
      self.withdraw()

    elif user_input=="4":
      print("check balance")
      self.check_balance()

    else:
      print("bye")

  def create_pin(self):
    self.pin=input("enter the pin")
    print("pin set succsefully")
    self.menu()   # 🔥 added

  def deposit(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      amount=int(input("enter thr amount to be deposited"))
      self.balance+=amount
      print("deposit succsef")
    else:
      print("incorrect pin")
    self.menu()   # 🔥 added

  def withdraw(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      amount=int(input("enter thr amount"))
      if amount<=self.balance:
        self.balance-=amount
        print("operation succsefull")
      else:
        print("insufficient balance")
    else:
      print("incorrect pin")
    self.menu()   # 🔥 added

  def check_balance(self):
    temp=input("enter the pin")
    if temp==self.pin:
      print("CORRECT PIN ENETERED")
      print("your balance is",self.balance)
    else:
      print("incorrect pin")
    self.menu()   # 🔥 added


obj=Atm()
# Out:
#                   Hello how would you like to proceed
#                   1)1 to create pin
#                   2)2 to deposit
#                   3)3 to withdraw
#                   4)to check balance click 4
#                   5)5 to exit1
# create pin
# enter the pin1234
# pin set succsefully
#
#                   Hello how would you like to proceed
#                   1)1 to create pin
#                   2)2 to deposit
#                   3)3 to withdraw
#                   4)to check balance click 4
#                   5)5 to exit2
# deposit
# enter the pin1234
# CORRECT PIN ENETERED
# enter thr amount to be deposited3440459
# deposit succsef
#
#                   Hello how would you like to proceed
#                   1)1 to create pin
#                   2)2 to deposit
#                   3)3 to withdraw
#                   4)to check balance click 4
#                   5)5 to exit5
# bye

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
x,y=load_diabetes(return_X_y=True)
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
reg.fcoef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])
