# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
df=pd.read_csv("cgpa_package_200.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.69     2.64
# 1  9.28     4.21
# 2  8.29     3.73
# 3  7.69     3.13
# 4  5.70     2.91

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
X=df.iloc[:,0:1]
Y=df.iloc[:,-1]
# Out:
# 0      2.64
# 1      4.21
# 2      3.73
# 3      3.13
# 4      2.91
#        ...
# 195    2.36
# 196    3.42
# 197    3.96
# 198    4.09
# 199    4.20
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_test
# Out:
# 112    4.01
# 29     1.85
# 182    4.37
# 199    4.20
# 193    3.49
# 85     2.79
# 10     2.39
# 54     3.50
# 115    3.53
# 35     3.80
# 12     4.16
# 92     3.35
# 13     2.60
# 126    3.86
# 174    3.80
# 2      3.73
# 44     2.31
# 3      3.13
# 113    3.45
# 14     2.66
# 23     3.07
# 25     4.20
# 6      1.77
# 134    4.07
# 165    3.79
# 173    2.15
# 45     3.54
# 65     3.15
# 48     3.34
# 122    2.42
# 178    4.11
# 64     2.40
# 9      3.83
# 57     3.60
# 78     2.59
# 71     1.96
# 128    2.05
# 176    3.74
# 131    2.13
# 53     3.73
# Name: package, dtype: float64

# %%
lr.predict([[3.68]])
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.39639109])

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
lr.score(X_test,Y_test)
# Out:
# 0.8241563823478462

# %% [markdown]
# multiplr linear regression

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
x,y=load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
# Out:
# (353, 10)

# %%
import numpy as np

class MyLR:

    def __init__(self):
        self.coef = None
        self.intercept = None

    def fit(self, x_train, y_train):
        x_train = np.insert(x_train, 0, 1, axis=1)

        betas = np.dot(
            np.linalg.inv(np.dot(x_train.T, x_train)),
            np.dot(x_train.T, y_train)
        )

        self.intercept = betas[0]
        self.coef = betas[1:]

        return betas

def predict(self, x_test):
    y_pred=np.dot(x_test,self.coef)+self.intercept
    return y_pred

# %%
lr=MyLR()
lr.fit(x_train,y_train)
# Out:
# array([ 151.88331005,   -9.15865318, -205.45432163,  516.69374454,
#         340.61999905, -895.5520019 ,  561.22067904,  153.89310954,
#         126.73139688,  861.12700152,   52.42112238])

# %%
y_test
# Out:
# array([ 73., 233.,  97., 111., 277., 341.,  64.,  68.,  65., 178., 142.,
#         77., 244., 115., 258.,  87., 220.,  86.,  74., 132., 136., 220.,
#         91., 235., 148., 317., 131.,  84.,  65., 217., 306.,  79., 158.,
#         54., 123., 174., 237., 212., 179., 281., 187., 200.,  68., 163.,
#        141., 202., 178., 242.,  47., 131., 243., 142., 200.,  89., 232.,
#         55., 253., 128., 104., 184., 110., 198.,  81., 195., 150.,  63.,
#        151., 233., 178.,  84., 237., 109., 131., 252., 200., 160., 200.,
#         51., 111.,  77., 201.,  88.,  78., 243., 268.,  55., 270., 288.,
#         91.])

# %%
lr.predict(x_test)
# Out:
# np.float64(154.12138809538376)

# %%
import numpy as np
from sklearn.metrics import r2_score

class MeraLR:

    def __init__(self):
        self.coef_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)

        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]

    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred


lr = MeraLR()
lr.fit(X_train,y_train)
print(X_train.shape)
print(np.insert(X_train,0,1,axis=1).shape)

y_pred = lr.predict(X_test)
print(r2_score(y_test,y_pred))

print(lr.coef_)
print(lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5203/3516938708.py in <cell line: 0>()
#      21
#      22 lr = MeraLR()
# ---> 23 lr.fit(X_train,y_train)
#      24 print(X_train.shape)
#      25 print(np.insert(X_train,0,1,axis=1).shape)
#
# NameError: name 'X_train' is not defined

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures,StandardScaler

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# generate data
X = 6*np.random.rand(200,1) - 3
y = 0.8*X**2 + 0.9*X + 2 + np.random.rand(200,1)


poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)


model = LinearRegression()
model.fit(X_poly, y)


x_new = np.linspace(X.min(), X.max(), 100).reshape(100,1)
x_new_poly = poly.transform(x_new)


y_pred = model.predict(x_new_poly)

# plot
plt.scatter(X, y)                 # data points
plt.plot(x_new, y_pred, linewidth=2)  # best-fit curve
plt.xlabel("X")
plt.ylabel("y")
plt.title("Polynomial Regression Fit")
plt.show()
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=2,test_size=0.2)

# %%
poly=PolynomialFeatures(degree=2,include_bias=False)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.fit_transform(x_test)
print(x_train[0])
print(x_train_poly[0])
# Out:
# [1.27023128]
# [1.27023128 1.6134875 ]

# %%
lr=LinearRegression()
lr.fit(x_train_poly,y_train)
y_pred=lr.predict(x_test_poly)
r2_score(y_test,y_pred)
# Out:
# 0.9865954464329147

# %%
print(lr.coef_)
# Out:
# [[0.89390185 0.79555749]]
